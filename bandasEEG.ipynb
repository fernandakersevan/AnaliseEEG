# %%
import pandas as pd
import matplotlib.pyplot as plt
# !pip install wget
import wget
# !pip install mne
# !pip install pymatreader
import mne
import numpy as np
import pickle
from scipy.signal import welch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=65bc90fec9fd7c9b3e631212471a03ccae7b2f16ca9914748f8f4fa42387ab18
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 16.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
     i = 11
     fs = 512

     runstring = '01'
     with open('/content/drive/MyDrive/PDPDFernanda2022/arquivosEEG_espectro/subj'+str(i)+'run'+runstring+'.pkl', 'rb') as handle:
         Peeg_limpo =  pickle.load(handle)
     w = np.arange(len(Peeg_limpo['Fp1']))*512/2/(len(Peeg_limpo['Fp1'])-1)

# %%
for i in range(11,12):
  istring = str(i).zfill(3)
  for run in range(6,11):
    runstring = str(run).zfill(2)
    with open('/content/drive/MyDrive/PDPDFernanda2022/arquivosEEG_espectro/subj'+str(i)+'run'+runstring+'.pkl', 'rb') as handle:
      Peeg_limpo =  pickle.load(handle)
    w = np.arange(len(Peeg_limpo['Fp1']))*512/2/(len(Peeg_limpo['Fp1'])-1)

# %%
plt.semilogx(w, Peeg_limpo['Fp1'])
delta = np.sum(Peeg_limpo['Fp1'][(w>=0.5) & (w<=4)]*w[1])
theta = np.sum(Peeg_limpo['Fp1'][(w>=4) & (w<=8)]*w[1])
alpha = np.sum(Peeg_limpo['Fp1'][(w>=8) & (w<=14)]*w[1])
beta = np.sum(Peeg_limpo['Fp1'][(w>=14) & (w<=30)]*w[1])
gamma = np.sum(Peeg_limpo['Fp1'][(w>=30)]*w[1])
print(delta, theta, alpha, beta, gamma)

# %%
plt.bar(['$\delta$', 'theta', 'alfa', 'beta', 'gamma'],
 [delta, theta, alpha, beta, gamma])
